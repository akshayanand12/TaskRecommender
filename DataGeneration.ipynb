# %%
import pandas as pd

# Define lists of activities and their corresponding metadata
activities_data = [
    {"Activity": "Walking 1000 steps", "Type": "Physical", "Duration (minutes)": 10, "Intensity": "Low"},
    {"Activity": "Sleep 8 hours", "Type": "Rest", "Duration (minutes)": 480, "Intensity": "Low"},
    {"Activity": "Jogging for 30 minutes", "Type": "Cardio", "Duration (minutes)": 30, "Intensity": "Medium"},
    {"Activity": "Yoga for 1 hour", "Type": "Flexibility", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "Cycling for 45 minutes", "Type": "Cardio", "Duration (minutes)": 45, "Intensity": "Medium"},
    {"Activity": "Swimming for 1 hour", "Type": "Cardio", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Meditation for 20 minutes", "Type": "Mental", "Duration (minutes)": 20, "Intensity": "Low"},
    {"Activity": "Strength training for 1 hour", "Type": "Strength", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Dancing for 30 minutes", "Type": "Cardio", "Duration (minutes)": 30, "Intensity": "Medium"},
    {"Activity": "Hiking for 2 hours", "Type": "Outdoor", "Duration (minutes)": 120, "Intensity": "Medium"},
    {"Activity": "Playing basketball for 1 hour", "Type": "Sports", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Playing soccer for 1.5 hours", "Type": "Sports", "Duration (minutes)": 90, "Intensity": "High"},
    {"Activity": "Rowing for 30 minutes", "Type": "Cardio", "Duration (minutes)": 30, "Intensity": "High"},
    {"Activity": "Pilates for 45 minutes", "Type": "Flexibility", "Duration (minutes)": 45, "Intensity": "Low"},
    {"Activity": "Rock climbing for 1 hour", "Type": "Strength", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Running 5 kilometers", "Type": "Cardio", "Duration (minutes)": 30, "Intensity": "High"},
    {"Activity": "Tennis for 1 hour", "Type": "Sports", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Golfing for 2 hours", "Type": "Leisure", "Duration (minutes)": 120, "Intensity": "Low"},
    {"Activity": "Playing badminton for 1 hour", "Type": "Sports", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Boxing for 1 hour", "Type": "Cardio", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Skipping rope for 15 minutes", "Type": "Cardio", "Duration (minutes)": 15, "Intensity": "High"},
    {"Activity": "Tai Chi for 1 hour", "Type": "Flexibility", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "Horseback riding for 1 hour", "Type": "Recreation", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "Snowboarding for 2 hours", "Type": "Outdoor", "Duration (minutes)": 120, "Intensity": "Medium"},
    {"Activity": "Skiing for 2 hours", "Type": "Outdoor", "Duration (minutes)": 120, "Intensity": "Medium"},
    {"Activity": "Surfing for 1 hour", "Type": "Water", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Kayaking for 1 hour", "Type": "Water", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Canoeing for 1 hour", "Type": "Water", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Playing volleyball for 1 hour", "Type": "Sports", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Zumba for 1 hour", "Type": "Cardio", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "CrossFit for 1 hour", "Type": "Strength", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Aerobics for 1 hour", "Type": "Cardio", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Spinning for 1 hour", "Type": "Cardio", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Gardening for 1 hour", "Type": "Leisure", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "House cleaning for 2 hours", "Type": "Physical", "Duration (minutes)": 120, "Intensity": "Medium"},
    {"Activity": "Walking the dog for 30 minutes", "Type": "Physical", "Duration (minutes)": 30, "Intensity": "Low"},
    {"Activity": "Playing with children for 1 hour", "Type": "Social", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Climbing stairs for 15 minutes", "Type": "Cardio", "Duration (minutes)": 15, "Intensity": "High"},
    {"Activity": "Jumping jacks for 10 minutes", "Type": "Cardio", "Duration (minutes)": 10, "Intensity": "High"},
    {"Activity": "Biking to work for 30 minutes", "Type": "Cardio", "Duration (minutes)": 30, "Intensity": "Medium"},
    {"Activity": "Walking in the park for 1 hour", "Type": "Leisure", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "Stretching for 30 minutes", "Type": "Flexibility", "Duration (minutes)": 30, "Intensity": "Low"},
    {"Activity": "Martial arts for 1 hour", "Type": "Strength", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Playing hockey for 1 hour", "Type": "Sports", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Skateboarding for 1 hour", "Type": "Outdoor", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Ice skating for 1 hour", "Type": "Outdoor", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Rollerblading for 1 hour", "Type": "Outdoor", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Frisbee for 1 hour", "Type": "Leisure", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "Jumping rope for 10 minutes", "Type": "Cardio", "Duration (minutes)": 10, "Intensity": "High"},
    {"Activity": "Walking uphill for 30 minutes", "Type": "Cardio", "Duration (minutes)": 30, "Intensity": "High"},
    {"Activity": "Walking downhill for 30 minutes", "Type": "Leisure", "Duration (minutes)": 30, "Intensity": "Low"},
    {"Activity": "Jogging on a treadmill for 30 minutes", "Type": "Cardio", "Duration (minutes)": 30, "Intensity": "Medium"},
    {"Activity": "Elliptical trainer for 30 minutes", "Type": "Cardio", "Duration (minutes)": 30, "Intensity": "Medium"},
    {"Activity": "Climbing a mountain for 4 hours", "Type": "Outdoor", "Duration (minutes)": 240, "Intensity": "High"},
    {"Activity": "Fishing for 2 hours", "Type": "Leisure", "Duration (minutes)": 120, "Intensity": "Low"},
    {"Activity": "Playing baseball for 1 hour", "Type": "Sports", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Playing rugby for 1 hour", "Type": "Sports", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Rowing machine for 30 minutes", "Type": "Cardio", "Duration (minutes)": 30, "Intensity": "High"},
    {"Activity": "Water polo for 1 hour", "Type": "Water", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Stand-up paddleboarding for 1 hour", "Type": "Water", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Scuba diving for 1 hour", "Type": "Water", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "Snorkeling for 1 hour", "Type": "Water", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "Windsurfing for 1 hour", "Type": "Water", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Kitesurfing for 1 hour", "Type": "Water", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Paragliding for 1 hour", "Type": "Air", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Skydiving for 1 hour", "Type": "Air", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Bungee jumping for 1 hour", "Type": "Air", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Caving for 2 hours", "Type": "Adventure", "Duration (minutes)": 120, "Intensity": "Medium"},
    {"Activity": "Sailing for 2 hours", "Type": "Water", "Duration (minutes)": 120, "Intensity": "Low"},
    {"Activity": "Stand-up desk for 8 hours", "Type": "Leisure", "Duration (minutes)": 480, "Intensity": "Low"},
    {"Activity": "Walking meeting for 1 hour", "Type": "Social", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "Office workout for 15 minutes", "Type": "Physical", "Duration (minutes)": 15, "Intensity": "Medium"},
    {"Activity": "Gym workout for 1 hour", "Type": "Physical", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Rowing on water for 1 hour", "Type": "Water", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Playing squash for 1 hour", "Type": "Sports", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Table tennis for 1 hour", "Type": "Sports", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Foosball for 1 hour", "Type": "Leisure", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "Dodgeball for 1 hour", "Type": "Sports", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Ultimate frisbee for 1 hour", "Type": "Sports", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Krav Maga for 1 hour", "Type": "Strength", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Capoeira for 1 hour", "Type": "Flexibility", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Judo for 1 hour", "Type": "Strength", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Fencing for 1 hour", "Type": "Sports", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Archery for 1 hour", "Type": "Skill", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "Laser tag for 1 hour", "Type": "Fun", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Paintball for 1 hour", "Type": "Fun", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Laser shooting for 1 hour", "Type": "Skill", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Virtual reality fitness for 1 hour", "Type": "Fun", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Darts for 1 hour", "Type": "Leisure", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "Bowling for 1 hour", "Type": "Leisure", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "Mini-golf for 1 hour", "Type": "Leisure", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "Croquet for 1 hour", "Type": "Leisure", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "Bocce ball for 1 hour", "Type": "Leisure", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "Shuffleboard for 1 hour", "Type": "Leisure", "Duration (minutes)": 60, "Intensity": "Low"},
    {"Activity": "Trampolining for 1 hour", "Type": "Fun", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Parkour for 1 hour", "Type": "Outdoor", "Duration (minutes)": 60, "Intensity": "High"},
    {"Activity": "Slacklining for 1 hour", "Type": "Balance", "Duration (minutes)": 60, "Intensity": "Medium"},
    {"Activity": "Aerial yoga for 1 hour", "Type": "Flexibility", "Duration (minutes)": 60, "Intensity": "Low"}
]

# Create a DataFrame
task = pd.DataFrame(activities_data)
task = task.reset_index().rename(columns={'index': 'taskid'})


# Display the DataFrame
# task.to_csv("data_new/tasks_new.csv", index=False)

# %%
import pandas as pd
import random

# Lists of example Singaporean names by ethnicity
chinese_names = [
    "Tan Ah Kow", "Lim Mei Ling", "Chen Wei", "Wang Fang", "Zhang Wei", "Lee Min Ho", "Liu Li", 
    "Chen Jia", "Chong Wei Ling", "Toh Chia Yi", "Goh Wen", "Ng Jia", "Ho Mei", "Gan Wei Ling",
    "Yeoh Mei", "Chang Ling", "Lin Wei", "Tan Ming", "Goh Siew", "Lee Siew", "Toh Wei", "Chen Wen"
]
malay_names = [
    "Ahmad bin Salim", "Siti binti Ahmad", "Firdaus bin Mohamad", "Hafiz bin Ali", "Nur binti Rahman", 
    "Syafiqah binti Ismail", "Hadi bin Musa", "Azman bin Salleh", "Liyana binti Razak", "Amirah binti Rahim",
    "Fatin binti Hakim", "Halim bin Zaid", "Aziz bin Osman", "Aisyah binti Hamid", "Siti binti Zainal",
    "Rashid bin Kadir", "Nadia binti Hassan", "Farah binti Kamal", "Azhar bin Rosli", "Rahman bin Isa"
]
indian_names = [
    "Rajesh Kumar", "Ananda Krishna", "Kumar Raj", "Suresh Menon", "Lakshmi Devi", "Aishwarya Reddy", 
    "Vijay Singh", "Meena Pillai", "Priya Rajan", "Shanti Devi", "Rahul Sharma", "Nisha Nair", 
    "Arjun Rao", "Karthik Subramaniam", "Deepa Anand", "Vivek Iyer", "Rekha Nair", "Amit Rao", 
    "Sangeeta Pillai", "Ravi Shankar"
]
eurasian_names = [
    "Christopher de Souza", "Melissa Pereira", "Julian Fernandez", "Deborah Matthews", "Peter Tan", 
    "Samantha Jones", "Andrew Fernandez", "Michelle Smith", "Rachel Lee", "John Pereira", 
    "Elizabeth Tan", "Nicholas Fernandez", "Karen Jones", "Michael Smith", "Linda Lee", 
    "Brian Tan", "Rebecca Pereira", "Daniel Fernandez", "Sandra Jones", "Robert Smith"
]

# Combine all names into one list
all_names = chinese_names + malay_names + indian_names + eurasian_names

# Ensure we have 100 unique names by repeating some if necessary
while len(all_names) < 100:
    all_names += all_names[:100 - len(all_names)]
random.shuffle(all_names)

# Define lists of potential motivations and overall health status
motivations = ["Weight Management", "Social Interaction", "Improve Sleep", "Increase Energy", "Reduce Stress", "Build Muscle"]
overall_health_status = ["Excellent", "Good", "Fair", "Poor"]

# Generate random metadata for each user
data = []
for name in all_names:
    age = random.randint(18, 65)  # Age between 18 and 65
    motivation = random.choice(motivations)
    health_status = random.choice(overall_health_status)
    data.append({"Name": name, "Age": age, "Motivation": motivation, "Overall Health Status": health_status})

# Create a DataFrame
user = pd.DataFrame(data)
user = user.reset_index().rename(columns={'index': 'userid'})

# Display the DataFrame
# user.to_csv("data_new/users_new.csv", index=False)

# %%
# Function to generate user-task interaction
import numpy as np

def generate_user_task_interaction(users, tasks):
    interactions = []
    skip_percentage = 40 # how many % to skip, 40% of the time, we will skip the interaction
    for (_, user) in users.iterrows():
        for (_, task) in tasks.iterrows():

            rand_num = random.randint(0, 100)
            if rand_num < skip_percentage:
                pass

            else:
                if (user["Motivation"] == "Weight Management" and task["Type"] == "Physical") or \
                    (user["Motivation"] == "Improve Sleep" and task["Type"] == "Rest") or \
                    (user["Motivation"] == "Increase Energy" and task["Type"] == "Cardio") or \
                    (user["Motivation"] == "Reduce Stress" and task["Type"] == "Flexibility") or \
                    (user["Motivation"] == "Build Muscle" and task["Type"] == "Strength") or \
                    (user["Motivation"] == "Social Interaction" and task["Type"] == "Outdoor"):
                    
                    mean = 0.75
                    std_dev = 0.3
                    completion_prob = np.random.normal(mean, std_dev)

                else:
                    mean = 0.45
                    std_dev = 0.3
                
                    completion_prob = np.random.normal(mean, std_dev)


                if user["Overall Health Status"] == "Poor" and task["Intensity"] == "Low":
                    completion_prob += 0.2
                elif ((user["Overall Health Status"] == "Fair") or (user["Overall Health Status"] == "Good")) and (task["Intensity"] == "Medium"):
                    completion_prob += 0.2
                elif user["Overall Health Status"] == "Excellent" and task["Intensity"] == "High":
                    completion_prob += 0.2
                else:
                    completion_prob -= 0.2

                completion = completion_prob > 0.5  # True if clipped_num > 0.5, False otherwise               
                interactions.append({"taskid": task["taskid"], "userid": user["userid"], "completion": completion})
    return interactions


interactions = generate_user_task_interaction(user, task)

task_user_interaction = pd.DataFrame(interactions)
task_user_interaction = task_user_interaction.reset_index().rename(columns={'index': 'interaction_id'})
task_user_interaction['completion'] = task_user_interaction['completion'].astype(int)

# task_user_interaction.to_csv("data_new/usertasks_new.csv", index=False)

# %%
import random
import numpy as np
import pandas as pd

def generate_user_task_interaction(users, tasks):
    interactions = []
    skip_percentage = 40  # how many % to skip, 40% of the time, we will skip the interaction

    for (_, user) in users.iterrows():
        for (_, task) in tasks.iterrows():

            rand_num = random.randint(0, 100)
            if rand_num < skip_percentage:
                continue

            # Calculate completion probability
            if (user["Motivation"] == "Weight Management" and task["Type"] == "Physical") or \
                (user["Motivation"] == "Improve Sleep" and task["Type"] == "Rest") or \
                (user["Motivation"] == "Increase Energy" and task["Type"] == "Cardio") or \
                (user["Motivation"] == "Reduce Stress" and task["Type"] == "Flexibility") or \
                (user["Motivation"] == "Build Muscle" and task["Type"] == "Strength") or \
                (user["Motivation"] == "Social Interaction" and task["Type"] == "Outdoor"):
                
                mean = 0.75
                std_dev = 0.3
                completion_prob = np.random.normal(mean, std_dev)

            else:
                mean = 0.45
                std_dev = 0.3
                completion_prob = np.random.normal(mean, std_dev)

            if user["Overall Health Status"] == "Poor" and task["Intensity"] == "Low":
                completion_prob += 0.2
            elif ((user["Overall Health Status"] == "Fair") or (user["Overall Health Status"] == "Good")) and (task["Intensity"] == "Medium"):
                completion_prob += 0.2
            elif user["Overall Health Status"] == "Excellent" and task["Intensity"] == "High":
                completion_prob += 0.2
            else:
                completion_prob -= 0.2

            completion = completion_prob > 0.5  # True if completion_prob > 0.5, False otherwise

            # Calculate like probability
            if (user["Motivation"] == "Weight Management" and task["Type"] == "Physical") or \
                (user["Motivation"] == "Improve Sleep" and task["Type"] == "Rest") or \
                (user["Motivation"] == "Increase Energy" and task["Type"] == "Cardio") or \
                (user["Motivation"] == "Reduce Stress" and task["Type"] == "Flexibility") or \
                (user["Motivation"] == "Build Muscle" and task["Type"] == "Strength") or \
                (user["Motivation"] == "Social Interaction" and task["Type"] == "Outdoor"):

                mean = 0.75
                std_dev = 0.3
                like_prob = np.random.normal(mean, std_dev)
            else:
                mean = 0.45
                std_dev = 0.3
                like_prob = np.random.normal(mean, std_dev)

            if user["Overall Health Status"] == "Poor" and task["Intensity"] == "Low":
                like_prob += 0.1
            elif ((user["Overall Health Status"] == "Fair") or (user["Overall Health Status"] == "Good")) and (task["Intensity"] == "Medium"):
                like_prob += 0.1
            elif user["Overall Health Status"] == "Excellent" and task["Intensity"] == "High":
                like_prob += 0.1
            else:
                like_prob -= 0.1

            like = like_prob > 0.5  # True if like_prob > 0.5, False otherwise

            interactions.append({
                "taskid": task["taskid"],
                "userid": user["userid"],
                "completion": completion,
                "like": like
            })

    return interactions


interactions = generate_user_task_interaction(user, task)

task_user_interaction = pd.DataFrame(interactions)
task_user_interaction = task_user_interaction.reset_index().rename(columns={'index': 'interaction_id'})
task_user_interaction['completion'] = task_user_interaction['completion'].astype(int)
task_user_interaction['like'] = task_user_interaction['like'].astype(int)

task_user_interaction.to_csv("data_new/usertasks_new_multi_tasks.csv", index=False)
