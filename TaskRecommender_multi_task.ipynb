# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
# %matplotlib inline

# %%
base_dir = "data/"

# %% [markdown]
# ## **Features**

# %%
# load users data
users = pd.read_csv(base_dir + "users.csv")
users.head()
# Out:
#    userid           Name  Age             Motivation  Segment
# 0       0    Karen Jones   28        Feeling Healthy        1
# 1       1        Lin Wei   43  Maintain Independence        3
# 2       2      Peter Tan   27          Manage Stress        2
# 3       3     Nisha Nair   28  Maintain Independence        3
# 4       4  Elizabeth Tan   46  Maintain Independence        1

# %%
# load task data
tasks = pd.read_csv(base_dir + "tasks.csv")
tasks.head()
# Out:
#    taskid                        Activity            Type  Duration (minutes)  \
# 0       0             Walking 10000 steps  Steps Tracking                  60
# 1       1              Jogging 5000 steps  Steps Tracking                  30
# 2       2              Running 7000 steps  Steps Tracking                  40
# 3       3       Starting daily step count     Start Steps                   5
# 4       4  Walking in place for 5 minutes     Start Steps                   5
#
#   Intensity
# 0       Low
# 1    Medium
# 2      High
# 3       Low
# 4       Low

# %%
# load user_task data
userTasks = pd.read_csv(base_dir + "usertasks.csv")
userTasks
# Out:
#       interaction_id  taskid  userid  completion   like
# 0                  0       0       0           1  False
# 1                  1       1       0           0  False
# 2                  2       2       0           0  False
# 3                  3       3       0           0  False
# 4                  4       4       0           0  False
# ...              ...     ...     ...         ...    ...
# 5884            5884      61      99           1   True
# 5885            5885      62      99           0  False
# 5886            5886      63      99           1   True
# 5887            5887      64      99           0  False
# 5888            5888      65      99           0   True
#
# [5889 rows x 5 columns]

# %% [markdown]
# ### Join users and tasks

# %%
# join users and tasks
userTasksFeature = pd.merge(userTasks, users, on=["userid"], how='left')
userTasksFeature = pd.merge(userTasksFeature, tasks, on=["taskid"], 
                            how='left')

userTasksFeature
# Out:
#       interaction_id  taskid  userid  completion   like            Name  Age  \
# 0                  0       0       0           1  False     Karen Jones   28
# 1                  1       1       0           0  False     Karen Jones   28
# 2                  2       2       0           0  False     Karen Jones   28
# 3                  3       3       0           0  False     Karen Jones   28
# 4                  4       4       0           0  False     Karen Jones   28
# ...              ...     ...     ...         ...    ...             ...  ...
# 5884            5884      61      99           1   True  Ananda Krishna   52
# 5885            5885      62      99           0  False  Ananda Krishna   52
# 5886            5886      63      99           1   True  Ananda Krishna   52
# 5887            5887      64      99           0  False  Ananda Krishna   52
# 5888            5888      65      99           0   True  Ananda Krishna   52
#
#            Motivation  Segment                            Activity  \
# 0     Feeling Healthy        1                 Walking 10000 steps
# 1     Feeling Healthy        1                  Jogging 5000 steps
# 2     Feeling Healthy        1                  Running 7000 steps
# 3     Feeling Healthy        1           Starting daily step count
# 4     Feeling Healthy        1      Walking in place for 5 minutes
# ...               ...      ...                                 ...
# 5884  Feeling Healthy        1  Breathing exercises for relaxation
# 5885  Feeling Healthy        1               Yoga for better sleep
# 5886  Feeling Healthy        1            Power nap during the day
# 5887  Feeling Healthy        1    Relaxation time in the afternoon
# 5888  Feeling Healthy        1           Meditation for relaxation
#
#                 Type  Duration (minutes) Intensity
# 0     Steps Tracking                  60       Low
# 1     Steps Tracking                  30    Medium
# 2     Steps Tracking                  40      High
# 3        Start Steps                   5       Low
# 4        Start Steps                   5       Low
# ...              ...                 ...       ...
# 5884  Sleep Exercise                  15       Low
# 5885  Sleep Exercise                  20       Low
# 5886  Sleep Recharge                  20       Low
# 5887  Sleep Recharge                  30       Low
# 5888  Sleep Recharge                  15       Low
#
# [5889 rows x 13 columns]

# %% [markdown]
# ## Split Data

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import pickle

# Preprocessing function for training data
def preprocess_for_decision_tree(df):
    # Define label encoders for categorical variables
    encoders = {
        'Motivation': LabelEncoder(),
        'Segment': LabelEncoder(),
        'Activity': LabelEncoder(),
        'Type': LabelEncoder(),
        'Intensity': LabelEncoder()
    }
    
    # Encode each categorical column
    for column, encoder in encoders.items():
        df[column] = encoder.fit_transform(df[column])
    
    # Rename columns for consistency and remove spaces
    df.columns = [col.replace(' ', '_') for col in df.columns]
    
    return df, encoders

# Function to save label encoders
def save_label_encoders(encoders, file_path):
    with open(file_path, 'wb') as file:
        pickle.dump(encoders, file)

# Function to load label encoders
def load_label_encoders(file_path):
    with open(file_path, 'rb') as file:
        encoders = pickle.load(file)
    return encoders

# Function to preprocess new data using loaded encoders
def preprocess_new_data(input_df, encoders):
    df = input_df.copy()
    for column, encoder in encoders.items():
        try:
            df[column] = encoder.transform(df[column])
        except:
            pass

    # Rename columns for consistency and remove spaces
    df.columns = [col.replace(' ', '_') for col in df.columns]
    
    return df

X = userTasksFeature.drop(['completion', 'like', 'interaction_id', 'taskid', 'userid', 'Name'] , axis=1)
y = userTasksFeature[["completion", "like"]].values


X, encoders = preprocess_for_decision_tree(X)
save_label_encoders(encoders, 'label_encoders.pkl')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.20, random_state=1)

# %% [markdown]
# ## Build Model

# %%
X_train
# Out:
#       Age  Motivation  Segment  Activity  Type  Duration_(minutes)  Intensity
# 1344   25           2        2        28     5                  15          1
# 5420   38           2        2         6    12                  20          1
# 3644   47           1        0        42     5                  30          1
# 4388   37           1        1        38     2                  10          1
# 2440   38           1        2         7    11                  20          2
# ...   ...         ...      ...       ...   ...                 ...        ...
# 905    33           1        2        11    21                  25          0
# 5192   47           1        1        16     6                  30          2
# 3980   63           0        2        38     2                  10          1
# 235    46           1        0        29    20                  30          2
# 5157   44           1        1        57    17                   5          1
#
# [4711 rows x 7 columns]

# %%
y_train
# Out:
# array([[0, False],
#        [0, False],
#        [0, False],
#        ...,
#        [0, True],
#        [0, False],
#        [0, True]], dtype=object)

# %%
import lightgbmmt as lgb
import numpy as np
from sklearn.metrics import roc_auc_score


num_labels = 2

def self_metric(preds, train_data):
    labels = train_data.get_label()
    labels2 = labels.reshape((num_labels, -1)).transpose()[:,0]
    preds2 = preds.reshape((num_labels, -1)).transpose()[:,0]
    preds2 = 1. / (1. + np.exp(-preds2))
    score = roc_auc_score(labels2, preds2)

    return 'self_metric', score, False


def mymse2(preds, train_data, ep = 0):
    labels = train_data.get_label()
    labels2 = labels.reshape((num_labels, -1)).transpose()
    preds2 = preds.reshape((num_labels, -1)).transpose()
    grad2 = (preds2 - labels2)
    grad = grad2 * np.array([1.5, 0.001])
    grad = np.sum(grad, axis = 1)
    grad2 = grad2.transpose().reshape((-1))
    hess = grad * 0. + 1
    hess2 = grad2 * 0. + 1
    return grad, hess, grad2, hess2

param = {
    'num_leaves': 48, 
    'max_depth': 6,
    'learning_rate': .03,
    'max_bin': 200,
    'lambda_l1': 0.1,
    'lambda_l2': 0.2,
    'verbose': 5,

    # multitask
    'objective': 'custom',
    'num_labels': num_labels, 
    'tree_learner': 'serial2',
    'num_threads': 4}    


evals_result_mt = {}
train_data = lgb.Dataset(X_train, label=y_train)
test_data = lgb.Dataset(X_test, label=y_test)
model = lgb.train(param,
                train_data,
                verbose_eval=10,
                fobj=mymse2, 
                feval=self_metric,
                num_boost_round=200,
                valid_sets=[test_data],
                evals_result=evals_result_mt)
model.set_num_labels(2)
# Out:
# [LightGBM] [Info] Length of label is not same with #data
# [LightGBM] [Warning] Using self-defined objective function
# [LightGBM] [Info] Total Bins 148
# [LightGBM] [Info] Number of data points in the train set: 4711, number of used features: 7
# [LightGBM] [Info] Length of label is not same with #data
# [LightGBM] [Warning] Using self-defined objective function
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 47 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 47 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and max_depth = 6
# [10]	valid_0's self_metric: 0.55311
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 47 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 47 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 34 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 34 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [20]	valid_0's self_metric: 0.563379
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 34 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 34 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 23 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 23 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 23 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 23 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [30]	valid_0's self_metric: 0.56577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 26 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 26 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 20 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 20 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 20 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 20 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 21 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 21 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [40]	valid_0's self_metric: 0.569121
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 26 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 26 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 43 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 43 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [50]	valid_0's self_metric: 0.579332
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 46 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 46 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 39 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 39 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 45 and max_depth = 6
# [60]	valid_0's self_metric: 0.585344
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 37 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 37 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 46 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 46 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 35 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 35 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 42 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 42 and max_depth = 6
# [70]	valid_0's self_metric: 0.587396
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 26 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 26 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 46 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 46 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 23 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 23 and max_depth = 6
# [80]	valid_0's self_metric: 0.587828
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 35 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 35 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 23 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 23 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [90]	valid_0's self_metric: 0.590174
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 34 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 34 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 38 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 38 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 6
# [100]	valid_0's self_metric: 0.592297
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 34 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 34 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 19 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 19 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 38 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 38 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [110]	valid_0's self_metric: 0.594011
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 19 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 19 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 39 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 39 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 38 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 38 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 42 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 42 and max_depth = 6
# [120]	valid_0's self_metric: 0.592362
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 34 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 34 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 46 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 46 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 26 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 26 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 19 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 19 and max_depth = 6
# [130]	valid_0's self_metric: 0.594641
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 19 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 19 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 37 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 37 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 19 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 19 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 19 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 19 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 43 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 43 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 39 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 39 and max_depth = 6
# [140]	valid_0's self_metric: 0.595482
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 38 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 38 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 26 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 26 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 26 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 26 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 39 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 39 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 39 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 39 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 38 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 38 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 37 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 37 and max_depth = 6
# [150]	valid_0's self_metric: 0.59378
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 40 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 40 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 42 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 42 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 23 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 23 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 42 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 42 and max_depth = 6
# [160]	valid_0's self_metric: 0.593842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 38 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 38 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 47 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 47 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 42 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 42 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 36 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 36 and max_depth = 6
# [170]	valid_0's self_metric: 0.592415
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 36 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 36 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 21 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 21 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 42 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 42 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 37 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 37 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 40 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 40 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [180]	valid_0's self_metric: 0.589991
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 37 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 37 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 36 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 36 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 39 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 39 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 36 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 36 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and max_depth = 6
# [190]	valid_0's self_metric: 0.587851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 36 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 36 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 36 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 36 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 43 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 43 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Debug] Trained a tree with leaves = 48 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and max_depth = 6
# [200]	valid_0's self_metric: 0.588012

# %%
import pickle

with open('model/model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
model.predict(X_test)
# Out:
# inner_predict 2356
# array([[0.331868  , 0.42453904],
#        [0.36373009, 0.41014847],
#        [0.42586556, 0.44912955],
#        ...,
#        [0.53867309, 0.42624756],
#        [0.36376169, 0.44990994],
#        [0.43382574, 0.41909875]])

# %% [markdown]
# ## Getting Predictions new a user

# %%
def create_prediction_for_user(user_df):
    loaded_encoders = load_label_encoders('label_encoders.pkl')
    user_inference_df = user_df.merge(tasks, how='cross') # cross join
    # create training data 
    user_processed_inference_df = preprocess_new_data(user_inference_df, loaded_encoders)
    user_processed_inference_df = user_processed_inference_df[["Age", "Motivation", "Segment", 
                                                               "Activity", "Type", "Duration_(minutes)", "Intensity"]]
    user_processed_inference_df = user_processed_inference_df.fillna(0)

    user_prediction = model.predict(user_processed_inference_df)

    user_prediction = pd.DataFrame(data=user_prediction, columns=["Completion Prob", "Like Prob"])
    output_df = pd.concat([user_inference_df, user_prediction], axis=1)
    output_df = output_df.sort_values(by="Completion Prob", ascending=False)

    return output_df

# %%
data = {
    'Name': ['Nate Lee'],
    'Age': [35],
    'Motivation': ['Feeling Healthy'],
    'Segment': ['1']
}

nate_df = pd.DataFrame(data)
nate_prediction = create_prediction_for_user(nate_df)
nate_prediction.head(20)
# Out:
# inner_predict 132
#         Name  Age       Motivation Segment  taskid  \
# 62  Nate Lee   35  Feeling Healthy       1      62
# 0   Nate Lee   35  Feeling Healthy       1       0
# 63  Nate Lee   35  Feeling Healthy       1      63
# 35  Nate Lee   35  Feeling Healthy       1      35
# 29  Nate Lee   35  Feeling Healthy       1      29
# 64  Nate Lee   35  Feeling Healthy       1      64
# 34  Nate Lee   35  Feeling Healthy       1      34
# 49  Nate Lee   35  Feeling Healthy       1      49
# 11  Nate Lee   35  Feeling Healthy       1      11
# 2   Nate Lee   35  Feeling Healthy       1       2
# 52  Nate Lee   35  Feeling Healthy       1      52
# 53  Nate Lee   35  Feeling Healthy       1      53
# 33  Nate Lee   35  Feeling Healthy       1      33
# 57  Nate Lee   35  Feeling Healthy       1      57
# 5   Nate Lee   35  Feeling Healthy       1       5
# 12  Nate Lee   35  Feeling Healthy       1      12
# 28  Nate Lee   35  Feeling Healthy       1      28
# 61  Nate Lee   35  Feeling Healthy       1      61
# 50  Nate Lee   35  Feeling Healthy       1      50
# 60  Nate Lee   35  Feeling Healthy       1      60
#
#                                    Activity                          Type  \
# 62                    Yoga for better sleep                Sleep Exercise
# 0                       Walking 10000 steps                Steps Tracking
# 63                 Power nap during the day                Sleep Recharge
# 35                 Using a meal logging app               Simple Meal Log
# 29                 10-minute desk stretches              Sedentary Simple
# 64         Relaxation time in the afternoon                Sleep Recharge
# 34    Recording food intake after each meal               Simple Meal Log
# 49               Using a sleep tracking app                Sleep Tracking
# 11                        10-minute cycling                    Start MVPA
# 2                        Running 7000 steps                Steps Tracking
# 52  Tracking energy levels after good sleep                 Sleep Benefit
# 53         Noting mental clarity post-sleep                 Sleep Benefit
# 33                      Logging meals daily               Simple Meal Log
# 57             Setting a consistent bedtime  Encourage Consistent Bedtime
# 5                 Pacing during phone calls                   Start Steps
# 12                  15-minute light jogging                Simple Aerobic
# 28                 5-minute chair exercises              Sedentary Simple
# 61       Breathing exercises for relaxation                Sleep Exercise
# 50                 Reviewing sleep patterns                Sleep Tracking
# 60              Light stretching before bed                Sleep Exercise
#
#     Duration (minutes) Intensity  Completion Prob  Like Prob
# 62                  20       Low         0.758466   0.492997
# 0                   60       Low         0.468615   0.344021
# 63                  20       Low         0.452985   0.406920
# 35                  15       Low         0.446268   0.366575
# 29                  10       Low         0.442088   0.400216
# 64                  30       Low         0.440259   0.410446
# 34                   5       Low         0.421177   0.441658
# 49                  10       Low         0.413413   0.312049
# 11                  10    Medium         0.411393   0.359703
# 2                   40      High         0.410207   0.376357
# 52                  10       Low         0.405784   0.364203
# 53                  10       Low         0.405587   0.374676
# 33                  10       Low         0.401117   0.398078
# 57                   5       Low         0.400872   0.458919
# 5                   10       Low         0.392345   0.367701
# 12                  15       Low         0.391385   0.352417
# 28                   5       Low         0.386406   0.434189
# 61                  15       Low         0.385556   0.402057
# 50                  15       Low         0.385418   0.357455
# 60                  10       Low         0.384127   0.410215

# %%
data = {
    'Name': ['Akshay Anand'],
    'Age': [40],
    'Motivation': ['Maintain Independence'],
    'Segment': ['2']
}

akshay_df = pd.DataFrame(data)
akshay_prediction = create_prediction_for_user(akshay_df)
akshay_prediction.head(20)
# Out:
# inner_predict 132
#             Name  Age             Motivation Segment  taskid  \
# 57  Akshay Anand   40  Maintain Independence       2      57
# 58  Akshay Anand   40  Maintain Independence       2      58
# 37  Akshay Anand   40  Maintain Independence       2      37
# 39  Akshay Anand   40  Maintain Independence       2      39
# 60  Akshay Anand   40  Maintain Independence       2      60
# 40  Akshay Anand   40  Maintain Independence       2      40
# 33  Akshay Anand   40  Maintain Independence       2      33
# 41  Akshay Anand   40  Maintain Independence       2      41
# 59  Akshay Anand   40  Maintain Independence       2      59
# 22  Akshay Anand   40  Maintain Independence       2      22
# 36  Akshay Anand   40  Maintain Independence       2      36
# 38  Akshay Anand   40  Maintain Independence       2      38
# 56  Akshay Anand   40  Maintain Independence       2      56
# 34  Akshay Anand   40  Maintain Independence       2      34
# 62  Akshay Anand   40  Maintain Independence       2      62
# 14  Akshay Anand   40  Maintain Independence       2      14
# 13  Akshay Anand   40  Maintain Independence       2      13
# 12  Akshay Anand   40  Maintain Independence       2      12
# 30  Akshay Anand   40  Maintain Independence       2      30
# 54  Akshay Anand   40  Maintain Independence       2      54
#
#                                   Activity                           Type  \
# 57            Setting a consistent bedtime   Encourage Consistent Bedtime
# 58              Creating a bedtime routine   Encourage Consistent Bedtime
# 37        Tracking energy levels post-meal               Meal Log Benefit
# 39  Substituting sugary snacks with fruits  Healthier Dietary Substitutes
# 60             Light stretching before bed                 Sleep Exercise
# 40  Replacing white bread with whole grain  Healthier Dietary Substitutes
# 33                     Logging meals daily                Simple Meal Log
# 41                Opting for lean proteins  Healthier Dietary Substitutes
# 59        Using an alarm to signal bedtime   Encourage Consistent Bedtime
# 22              20-minute sprint intervals               Vigorous Aerobic
# 36   Noting down benefits of healthy meals               Meal Log Benefit
# 38            Reviewing nutritional values               Meal Log Benefit
# 56        Practicing relaxation techniques         Improve Sleep Duration
# 34   Recording food intake after each meal                Simple Meal Log
# 62                   Yoga for better sleep                 Sleep Exercise
# 14                  20-minute easy cycling                 Simple Aerobic
# 13                 20-minute dance session                 Simple Aerobic
# 12                 15-minute light jogging                 Simple Aerobic
# 30             Try a new sport or activity               Exercise Variety
# 54         Going to bed 15 minutes earlier         Improve Sleep Duration
#
#     Duration (minutes) Intensity  Completion Prob  Like Prob
# 57                   5       Low         0.650845   0.415734
# 58                  20       Low         0.593886   0.438838
# 37                  10       Low         0.555513   0.404369
# 39                  10       Low         0.550090   0.451139
# 60                  10       Low         0.535231   0.419160
# 40                  10       Low         0.534593   0.435379
# 33                  10       Low         0.532077   0.420293
# 41                  10       Low         0.531521   0.434850
# 59                   5       Low         0.525023   0.366150
# 22                  20      High         0.518958   0.338998
# 36                  10       Low         0.518427   0.423917
# 38                  15       Low         0.515380   0.422507
# 56                  30       Low         0.510697   0.417457
# 34                   5       Low         0.510310   0.422356
# 62                  20       Low         0.505610   0.393731
# 14                  20       Low         0.499896   0.381467
# 13                  20       Low         0.499870   0.376454
# 12                  15       Low         0.497971   0.386841
# 30                  30    Medium         0.491550   0.401102
# 54                  15       Low         0.486361   0.424925
