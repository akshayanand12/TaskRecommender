# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
# %matplotlib inline

# %%
base_dir = "data_new/"

# %% [markdown]
# ## **Features**

# %%
# load users data
users = pd.read_csv(base_dir + "users_new.csv")
users.head()
# Out:
#    userid               Name  Age       Motivation Overall Health Status
# 0       0             Liu Li   49    Reduce Stress                  Poor
# 1       1     Samantha Jones   50     Build Muscle                  Fair
# 2       2  Siti binti Zainal   18  Increase Energy                  Fair
# 3       3      Michael Smith   55     Build Muscle                  Poor
# 4       4         Tan Ah Kow   46     Build Muscle                  Fair

# %%
# load task data
tasks = pd.read_csv(base_dir + "tasks_new.csv")
tasks.head()
# Out:
#    taskid                Activity         Type  Duration (minutes) Intensity
# 0       0      Walking 1000 steps     Physical                  10       Low
# 1       1           Sleep 8 hours         Rest                 480       Low
# 2       2  Jogging for 30 minutes       Cardio                  30    Medium
# 3       3         Yoga for 1 hour  Flexibility                  60       Low
# 4       4  Cycling for 45 minutes       Cardio                  45    Medium

# %%
# load user_task data
userTasks = pd.read_csv(base_dir + "usertasks_new.csv")
userTasks
# Out:
#       interaction_id  taskid  userid  completion
# 0                  0       0       0           1
# 1                  1       1       0           1
# 2                  2       2       0           0
# 3                  3       6       0           0
# 4                  4       9       0           1
# ...              ...     ...     ...         ...
# 5919            5919      93      99           0
# 5920            5920      94      99           1
# 5921            5921      95      99           0
# 5922            5922      96      99           1
# 5923            5923      97      99           1
#
# [5924 rows x 4 columns]

# %% [markdown]
# ### Join users and tasks

# %%
#join users and tasks
userTasksFeature = pd.merge(userTasks, users, on=["userid"], how='left')
userTasksFeature = pd.merge(userTasksFeature, tasks, on=["taskid"], 
                            how='left')

userTasksFeature
# Out:
#       interaction_id  taskid  userid  completion          Name  Age  \
# 0                  0       0       0           1        Liu Li   49
# 1                  1       1       0           1        Liu Li   49
# 2                  2       2       0           0        Liu Li   49
# 3                  3       6       0           0        Liu Li   49
# 4                  4       9       0           1        Liu Li   49
# ...              ...     ...     ...         ...           ...  ...
# 5919            5919      93      99           0  Gan Wei Ling   20
# 5920            5920      94      99           1  Gan Wei Ling   20
# 5921            5921      95      99           0  Gan Wei Ling   20
# 5922            5922      96      99           1  Gan Wei Ling   20
# 5923            5923      97      99           1  Gan Wei Ling   20
#
#          Motivation Overall Health Status                   Activity  \
# 0     Reduce Stress                  Poor         Walking 1000 steps
# 1     Reduce Stress                  Poor              Sleep 8 hours
# 2     Reduce Stress                  Poor     Jogging for 30 minutes
# 3     Reduce Stress                  Poor  Meditation for 20 minutes
# 4     Reduce Stress                  Poor         Hiking for 2 hours
# ...             ...                   ...                        ...
# 5919  Improve Sleep                  Good    Shuffleboard for 1 hour
# 5920  Improve Sleep                  Good    Trampolining for 1 hour
# 5921  Improve Sleep                  Good         Parkour for 1 hour
# 5922  Improve Sleep                  Good     Slacklining for 1 hour
# 5923  Improve Sleep                  Good     Aerial yoga for 1 hour
#
#              Type  Duration (minutes) Intensity
# 0        Physical                  10       Low
# 1            Rest                 480       Low
# 2          Cardio                  30    Medium
# 3          Mental                  20       Low
# 4         Outdoor                 120    Medium
# ...           ...                 ...       ...
# 5919      Leisure                  60       Low
# 5920          Fun                  60    Medium
# 5921      Outdoor                  60      High
# 5922      Balance                  60    Medium
# 5923  Flexibility                  60       Low
#
# [5924 rows x 12 columns]

# %% [markdown]
# ## Split Data

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import pickle

# Preprocessing function for training data
def preprocess_for_decision_tree(df):
    # Define label encoders for categorical variables
    encoders = {
        'Motivation': LabelEncoder(),
        'Overall Health Status': LabelEncoder(),
        'Activity': LabelEncoder(),
        'Type': LabelEncoder(),
        'Intensity': LabelEncoder()
    }
    
    # Encode each categorical column
    for column, encoder in encoders.items():
        df[column] = encoder.fit_transform(df[column])
    
    # Rename columns for consistency and remove spaces
    df.columns = [col.replace(' ', '_') for col in df.columns]
    
    return df, encoders

# Function to save label encoders
def save_label_encoders(encoders, file_path):
    with open(file_path, 'wb') as file:
        pickle.dump(encoders, file)

# Function to load label encoders
def load_label_encoders(file_path):
    with open(file_path, 'rb') as file:
        encoders = pickle.load(file)
    return encoders

# Function to preprocess new data using loaded encoders
def preprocess_new_data(input_df, encoders):
    df = input_df.copy()
    for column, encoder in encoders.items():
        try:
            df[column] = encoder.transform(df[column])
        except:
            pass

    # Rename columns for consistency and remove spaces
    df.columns = [col.replace(' ', '_') for col in df.columns]
    
    return df

X = userTasksFeature.drop(['completion', 'interaction_id', 'taskid', 'userid', 'Name'] , axis=1)
y = userTasksFeature["completion"]

X, encoders = preprocess_for_decision_tree(X)
save_label_encoders(encoders, 'label_encoders.pkl')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.20, random_state=1)

# %% [markdown]
# ##Build Model

# %%
model = GradientBoostingClassifier(random_state=1)
model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=1)

# %% [markdown]
# ## Scoring

# %%
print("Accuracy on training set : ",model.score(X_train, y_train))
print("Accuracy on test set : ",model.score(X_test, y_test))
# Out:
# Accuracy on training set :  0.7524794260392488
# Accuracy on test set :  0.7341772151898734

# %%
#Checking number of positives
y.value_counts(1)
# Out:
# completion
# 0    0.618839
# 1    0.381161
# Name: proportion, dtype: float64

# %% [markdown]
# ## Confusion Matrix

# %%
# Inference

y_test_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_test_pred)
# Out:
# array([[633,  97],
#        [218, 237]])

# %% [markdown]
# ## Getting Predictions new a user

# %%
def create_prediction_for_user(user_df):
    loaded_encoders = load_label_encoders('label_encoders.pkl')
    user_inference_df = user_df.merge(tasks, how='cross') # cross join
    # create training data 
    user_processed_inference_df = preprocess_new_data(user_inference_df, loaded_encoders)
    user_processed_inference_df = user_processed_inference_df[["Age", "Motivation", "Overall_Health_Status", 
                                                               "Activity", "Type", "Duration_(minutes)", "Intensity"]]
    user_processed_inference_df = user_processed_inference_df.fillna(0)

    user_prediction = model.predict_proba(user_processed_inference_df)

    user_prediction = pd.DataFrame(user_prediction)
    output_df = pd.concat([user_inference_df, user_prediction], axis=1)
    output_df = output_df.sort_values(by=1, ascending=False)

    return output_df

# %%
data = {
    'Name': ['Nate Lee'],
    'Age': [35],
    'Motivation': ['Improve Sleep'],
    'Overall Health Status': ['Poor']
}

nate_df = pd.DataFrame(data)
nate_prediction = create_prediction_for_user(nate_df)
nate_prediction.head(20)
# Out:
#         Name  Age     Motivation Overall Health Status  taskid  \
# 97  Nate Lee   35  Improve Sleep                  Poor      97
# 0   Nate Lee   35  Improve Sleep                  Poor       0
# 92  Nate Lee   35  Improve Sleep                  Poor      92
# 89  Nate Lee   35  Improve Sleep                  Poor      89
# 35  Nate Lee   35  Improve Sleep                  Poor      35
# 83  Nate Lee   35  Improve Sleep                  Poor      83
# 50  Nate Lee   35  Improve Sleep                  Poor      50
# 40  Nate Lee   35  Improve Sleep                  Poor      40
# 1   Nate Lee   35  Improve Sleep                  Poor       1
# 69  Nate Lee   35  Improve Sleep                  Poor      69
# 88  Nate Lee   35  Improve Sleep                  Poor      88
# 22  Nate Lee   35  Improve Sleep                  Poor      22
# 17  Nate Lee   35  Improve Sleep                  Poor      17
# 29  Nate Lee   35  Improve Sleep                  Poor      29
# 6   Nate Lee   35  Improve Sleep                  Poor       6
# 31  Nate Lee   35  Improve Sleep                  Poor      31
# 70  Nate Lee   35  Improve Sleep                  Poor      70
# 93  Nate Lee   35  Improve Sleep                  Poor      93
# 54  Nate Lee   35  Improve Sleep                  Poor      54
# 33  Nate Lee   35  Improve Sleep                  Poor      33
#
#                            Activity         Type  Duration (minutes)  \
# 97           Aerial yoga for 1 hour  Flexibility                  60
# 0                Walking 1000 steps     Physical                  10
# 92            Bocce ball for 1 hour      Leisure                  60
# 89               Bowling for 1 hour      Leisure                  60
# 35   Walking the dog for 30 minutes     Physical                  30
# 83               Archery for 1 hour        Skill                  60
# 50  Walking downhill for 30 minutes      Leisure                  30
# 40   Walking in the park for 1 hour      Leisure                  60
# 1                     Sleep 8 hours         Rest                 480
# 69        Stand-up desk for 8 hours      Leisure                 480
# 88                 Darts for 1 hour      Leisure                  60
# 22      Horseback riding for 1 hour   Recreation                  60
# 17              Golfing for 2 hours      Leisure                 120
# 29                 Zumba for 1 hour       Cardio                  60
# 6         Meditation for 20 minutes       Mental                  20
# 31              Aerobics for 1 hour       Cardio                  60
# 70       Walking meeting for 1 hour       Social                  60
# 93          Shuffleboard for 1 hour      Leisure                  60
# 54              Fishing for 2 hours      Leisure                 120
# 33             Gardening for 1 hour      Leisure                  60
#
#    Intensity         0         1
# 97       Low  0.284516  0.715484
# 0        Low  0.415617  0.584383
# 92       Low  0.428135  0.571865
# 89       Low  0.428135  0.571865
# 35       Low  0.440379  0.559621
# 83       Low  0.443844  0.556156
# 50       Low  0.453140  0.546860
# 40       Low  0.456737  0.543263
# 1        Low  0.459803  0.540197
# 69       Low  0.472651  0.527349
# 88       Low  0.488440  0.511560
# 22       Low  0.528789  0.471211
# 17       Low  0.529310  0.470690
# 29      High  0.534374  0.465626
# 6        Low  0.537211  0.462789
# 31    Medium  0.540969  0.459031
# 70       Low  0.544516  0.455484
# 93       Low  0.546056  0.453944
# 54       Low  0.546056  0.453944
# 33       Low  0.547551  0.452449

# %%
data = {
    'Name': ['Akshay Anand'],
    'Age': [40],
    'Motivation': ['Increase Energy'],
    'Overall Health Status': ['Excellent']
}

akshay_df = pd.DataFrame(data)
akshay_prediction = create_prediction_for_user(akshay_df)
akshay_prediction.head(20)
# Out:
#             Name  Age       Motivation Overall Health Status  taskid  \
# 29  Akshay Anand   40  Increase Energy             Excellent      29
# 49  Akshay Anand   40  Increase Energy             Excellent      49
# 5   Akshay Anand   40  Increase Energy             Excellent       5
# 32  Akshay Anand   40  Increase Energy             Excellent      32
# 19  Akshay Anand   40  Increase Energy             Excellent      19
# 66  Akshay Anand   40  Increase Energy             Excellent      66
# 37  Akshay Anand   40  Increase Energy             Excellent      37
# 12  Akshay Anand   40  Increase Energy             Excellent      12
# 57  Akshay Anand   40  Increase Energy             Excellent      57
# 38  Akshay Anand   40  Increase Energy             Excellent      38
# 48  Akshay Anand   40  Increase Energy             Excellent      48
# 15  Akshay Anand   40  Increase Energy             Excellent      15
# 20  Akshay Anand   40  Increase Energy             Excellent      20
# 65  Akshay Anand   40  Increase Energy             Excellent      65
# 14  Akshay Anand   40  Increase Energy             Excellent      14
# 72  Akshay Anand   40  Increase Energy             Excellent      72
# 95  Akshay Anand   40  Increase Energy             Excellent      95
# 80  Akshay Anand   40  Increase Energy             Excellent      80
# 42  Akshay Anand   40  Increase Energy             Excellent      42
# 43  Akshay Anand   40  Increase Energy             Excellent      43
#
#                           Activity         Type  Duration (minutes) Intensity  \
# 29                Zumba for 1 hour       Cardio                  60      High
# 49   Walking uphill for 30 minutes       Cardio                  30      High
# 5              Swimming for 1 hour       Cardio                  60      High
# 32             Spinning for 1 hour       Cardio                  60      High
# 19               Boxing for 1 hour       Cardio                  60      High
# 66       Bungee jumping for 1 hour          Air                  60      High
# 37  Climbing stairs for 15 minutes       Cardio                  15      High
# 12           Rowing for 30 minutes       Cardio                  30      High
# 57   Rowing machine for 30 minutes       Cardio                  30      High
# 38    Jumping jacks for 10 minutes       Cardio                  10      High
# 48     Jumping rope for 10 minutes       Cardio                  10      High
# 15            Running 5 kilometers       Cardio                  30      High
# 20    Skipping rope for 15 minutes       Cardio                  15      High
# 65            Skydiving for 1 hour          Air                  60      High
# 14        Rock climbing for 1 hour     Strength                  60      High
# 72          Gym workout for 1 hour     Physical                  60      High
# 95              Parkour for 1 hour      Outdoor                  60      High
# 80             Capoeira for 1 hour  Flexibility                  60      High
# 42         Martial arts for 1 hour     Strength                  60      High
# 43       Playing hockey for 1 hour       Sports                  60      High
#
#            0         1
# 29  0.187972  0.812028
# 49  0.245874  0.754126
# 5   0.268145  0.731855
# 32  0.268145  0.731855
# 19  0.272693  0.727307
# 66  0.274865  0.725135
# 37  0.275541  0.724459
# 12  0.276033  0.723967
# 57  0.276033  0.723967
# 38  0.281331  0.718669
# 48  0.281331  0.718669
# 15  0.291700  0.708300
# 20  0.298082  0.701918
# 65  0.306441  0.693559
# 14  0.357850  0.642150
# 72  0.364679  0.635321
# 95  0.376156  0.623844
# 80  0.390783  0.609217
# 42  0.398851  0.601149
# 43  0.399034  0.600966

# %%
# Illustration of cold start 
data = {
    'Name': ['Zhenxuan'],
    'Age': [None],
    'Motivation': ['Build Muscle'],
    'Overall Health Status': [None]
}

zhenxuan_df = pd.DataFrame(data)
zhenxuan_prediction = create_prediction_for_user(zhenxuan_df)
zhenxuan_prediction.head(20)
# Out:
#         Name   Age    Motivation Overall Health Status  taskid  \
# 30  Zhenxuan  None  Build Muscle                  None      30
# 77  Zhenxuan  None  Build Muscle                  None      77
# 82  Zhenxuan  None  Build Muscle                  None      82
# 14  Zhenxuan  None  Build Muscle                  None      14
# 42  Zhenxuan  None  Build Muscle                  None      42
# 19  Zhenxuan  None  Build Muscle                  None      19
# 81  Zhenxuan  None  Build Muscle                  None      81
# 79  Zhenxuan  None  Build Muscle                  None      79
# 37  Zhenxuan  None  Build Muscle                  None      37
# 7   Zhenxuan  None  Build Muscle                  None       7
# 63  Zhenxuan  None  Build Muscle                  None      63
# 66  Zhenxuan  None  Build Muscle                  None      66
# 49  Zhenxuan  None  Build Muscle                  None      49
# 25  Zhenxuan  None  Build Muscle                  None      25
# 80  Zhenxuan  None  Build Muscle                  None      80
# 29  Zhenxuan  None  Build Muscle                  None      29
# 43  Zhenxuan  None  Build Muscle                  None      43
# 56  Zhenxuan  None  Build Muscle                  None      56
# 10  Zhenxuan  None  Build Muscle                  None      10
# 62  Zhenxuan  None  Build Muscle                  None      62
#
#                           Activity         Type  Duration (minutes) Intensity  \
# 30             CrossFit for 1 hour     Strength                  60      High
# 77            Dodgeball for 1 hour       Sports                  60      High
# 82              Fencing for 1 hour       Sports                  60      High
# 14        Rock climbing for 1 hour     Strength                  60      High
# 42         Martial arts for 1 hour     Strength                  60      High
# 19               Boxing for 1 hour       Cardio                  60      High
# 81                 Judo for 1 hour     Strength                  60      High
# 79            Krav Maga for 1 hour     Strength                  60      High
# 37  Climbing stairs for 15 minutes       Cardio                  15      High
# 7     Strength training for 1 hour     Strength                  60      High
# 63          Kitesurfing for 1 hour        Water                  60      High
# 66       Bungee jumping for 1 hour          Air                  60      High
# 49   Walking uphill for 30 minutes       Cardio                  30      High
# 25              Surfing for 1 hour        Water                  60      High
# 80             Capoeira for 1 hour  Flexibility                  60      High
# 29                Zumba for 1 hour       Cardio                  60      High
# 43       Playing hockey for 1 hour       Sports                  60      High
# 56        Playing rugby for 1 hour       Sports                  60      High
# 10   Playing basketball for 1 hour       Sports                  60      High
# 62          Windsurfing for 1 hour        Water                  60      High
#
#            0         1
# 30  0.125253  0.874747
# 77  0.190195  0.809805
# 82  0.190195  0.809805
# 14  0.239781  0.760219
# 42  0.268028  0.731972
# 19  0.269350  0.730650
# 81  0.272117  0.727883
# 79  0.272117  0.727883
# 37  0.274229  0.725771
# 7   0.279522  0.720478
# 63  0.308361  0.691639
# 66  0.312754  0.687246
# 49  0.318800  0.681200
# 25  0.318990  0.681010
# 80  0.324072  0.675928
# 29  0.325874  0.674126
# 43  0.326065  0.673935
# 56  0.326065  0.673935
# 10  0.326065  0.673935
# 62  0.326492  0.673508
